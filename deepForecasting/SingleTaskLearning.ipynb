# %%
import torch
import torch.nn as nn
import numpy as np
import pandas as pd
import os
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import copy
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error
from collections import defaultdict
from torch.utils.data import TensorDataset, DataLoader

# %%
bkdatafolder = "/Volumes/T7 Touch/TheseProject/DR_KELLA/BKDataCleaned/"
dataset_name = os.listdir(bkdatafolder)

# %%
def createDictFloor(floor_name):
    getdict = {}
    floors = [floor for floor in dataset_name if floor_name in floor]
    for name in floors:
        floorname = name.split(".")[0]
        getdict[floorname] = pd.read_csv(bkdatafolder+name, index_col=0, parse_dates=["Date"])
        getdict[floorname] = getdict[floorname].sort_index()
    return getdict

def Missing_values(data):
    total = data.isnull().sum().sort_values(ascending=False)
    percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total,percent], axis=1, keys=['Total', 'Pourcentage'])
    print (missing_data[(percent>0)],'\n' )

def seed_everything(seed=0):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    
def createPlot(date1, date2, features, data):
    for floor in data.keys():
        data[floor].resample("5T").mean()[features][date1:date2].plot(figsize=(20,7))
        

def createDTFeat(date1, date2, datadict, features, resample_method="sum" ,scale=True):
    resample_move = {}
    index_nan = {}
    index_small = {}
    floors = list(datadict.keys())
    dates = []
    scalers = {}
    for data in datadict.keys():
        if resample_method == "sum":
            resample_move[data] = floor_dict[data][date1:date2].resample(
                "5min").sum()
            
        elif resample_method == "max":
            resample_move[data] = floor_dict[data][date1:date2].resample(
                "5min").max().bfill()
        elif resample_method == "mean":
            resample_move[data] = floor_dict[data][date1:date2].resample(
                "5min").mean().bfill()
            
        cols = resample_move[data].columns
        idx = resample_move[data].index

        if scale:
            scaler = MinMaxScaler()
            scaler.fit(resample_move[data])
            resample_move[data] = pd.DataFrame(scaler.transform(
                resample_move[data]),
                                               columns=cols,
                                               index=idx)
            scalers[data] = scaler

        resample_move[data]["weekday"] = resample_move[data].index.day_name()
        resample_move[data]["date"] = resample_move[data].index.date
        resample_move[data]["time"] = resample_move[data].index.time

        nan = np.where(pd.isnull(resample_move[data][features]))[0]
        index_nan[data] = np.unique(resample_move[data].iloc[nan]["time"])

    return resample_move, scalers, index_nan

def getInfoTimeShape(datadict):
    for floor in datadict.keys():
        data = datadict[floor]
        print("Floor : {} , shape :{} , TimeMin {} , TimeMax {}".format(floor,data.shape, data.index.min(), data.index.max()))
        Missing_values(data)
        
def cleanNan(data,idx_nan):
    index=[]
    for k,v in idx_nan.items():
        for ele in v:
            index.append(ele)
    mynan = set(index)
    newdata = data.copy()
    remain_date = []
    for floor in idx_nan.keys():
        datafloor = data[floor]
        todropnan = datafloor[datafloor["date"].isin(list(mynan))].index
        datafloor = datafloor.drop(todropnan)
        newdata[floor] = datafloor
        for date in datafloor["date"]:
            remain_date.append(str(date))
    remain_date = sorted(set(remain_date))
    return data, remain_date

# %%
def rolling_window(series, window_size):
    return np.array([series[i : (i + window_size)] for i in range(0, series.shape[0] - window_size + 1)])

def to_timeseries_input(series, lookback, predictions):
    inputs = rolling_window(series[:-predictions], lookback)
    outputs = rolling_window(series[lookback:], predictions)
    return inputs, outputs

def createDataByDate(datadict, features, dates):
    databyDate = defaultdict(lambda : defaultdict(dict))
    for date in dates:
        for floor in datadict.keys():
            databyDate[date][floor] = np.asarray(datadict[floor][date][features])
    return databyDate

def splitDate(dates,cutoff):
    train_date = [x for x in dates if x <= cutoff]
    test_date = sorted(list(set(dates) - set(train_date)))
    return train_date, test_date

def getInfoDataByDate(data, dates):
    for date in dates:
        print("Date : {}".format(date))
        for floor in data[date]:
            print("{} shape : {}".format(floor,data[date][floor].shape))
            
def LoaderByZone(data,zone_name,dates, lookback, lookahead, batch_size, shuffle=False):
    loaderZ = {}
    for i,date in enumerate(dates):
        haruharu = data[date][zone_name]
        trainx, trainy = to_timeseries_input(haruharu, lookback, lookahead,)
        xshape = torch.tensor(trainx, dtype=torch.float).unsqueeze(-1)
        yshape = torch.tensor(trainy, dtype=torch.float)
        tensorwrap = TensorDataset(xshape,yshape)
        loaderxy = DataLoader(tensorwrap,batch_size = batch_size, shuffle=shuffle, drop_last=True)
        loaderZ[date] = loaderxy
    return loaderZ

def LoaderByZoneXY(dataX, dataY, zone_name,dates, seq_len, batch_size, shuffle=False):
    loaderZ = {}
    for i,date in enumerate(dates):
        trainx = rolling_window(dataX[date][zone_name], seq_len)
        trainy = rolling_window(dataY[date][zone_name], seq_len)
        xshape = torch.tensor(trainx, dtype=torch.float).unsqueeze(-1)
        yshape = torch.tensor(trainy, dtype=torch.float)
        tensorwrap = TensorDataset(xshape,yshape)
        loaderxy = DataLoader(tensorwrap,batch_size = batch_size, shuffle=shuffle, drop_last=True)
        loaderZ[date] = loaderxy
    return loaderZ

def LoaderXYtrain(dataX, dataY, zone_name, dates, seq_len, batch_size, shuffle=False, val = True):
    myX = rolling_window(dataX[dates[0]][zone_name], seq_len)
    myY = rolling_window(dataY[dates[0]][zone_name], seq_len)
    for date in dates:
        seqX = rolling_window(dataX[date][zone_name], seq_len)
        seqY = rolling_window(dataY[date][zone_name], seq_len)
        myX = np.vstack((myX, seqX))
        myY = np.vstack((myY, seqY))
    xshape = torch.tensor(myX, dtype=torch.float).unsqueeze(-1)
    yshape = torch.tensor(myY, dtype=torch.float)
    tensorwrap = TensorDataset(xshape, yshape)
    total_data = len(tensorwrap)
    if val:
        train_size = int(0.8*total_data)
        train_set, val_set = torch.utils.data.random_split(tensorwrap, [train_size, total_data - train_size],
                                                          generator=torch.Generator().manual_seed(0))
        loadertrain = DataLoader(train_set, batch_size = batch_size, shuffle=shuffle, drop_last=True)
        loaderval = DataLoader(val_set, batch_size = batch_size, shuffle=shuffle, drop_last=True)
        return loadertrain, loaderval
    else :
        loaderxy = DataLoader(tensorwrap, batch_size= batch_size, shuffle=shuffle, drop_last=True)
        return loaderxy

# %%
date1 = "2019-03-07"
date2 = "2019-12-31"
floor_dict = createDictFloor("Floor7")
for data in floor_dict.keys():
    zone = floor_dict[data]
    print("{} Start: {} End: {} Count:{}".format(data,zone.index.min(),zone.index.max(), zone.shape[0]))
    print("")
# Out:
# Floor7Z1 Start: 2019-03-06 14:50:00 End: 2019-12-31 23:59:00 Count:424099
#
# Floor7Z2 Start: 2019-03-06 14:48:00 End: 2019-12-31 23:59:00 Count:424701
#
# Floor7Z4 Start: 2019-03-06 14:46:00 End: 2019-12-31 23:59:00 Count:416243
#
# Floor7Z5 Start: 2019-03-06 14:55:00 End: 2019-12-31 23:59:00 Count:407698

# %% [markdown]
# # Model

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, hid_dim, n_layers=1):
        super(Encoder,self).__init__()
        self.input_dim = input_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        self.lstm = nn.LSTM(input_dim, hid_dim, n_layers, batch_first=False, bias=False)
        
    def forward(self, seq):
        outputs, self.hidden = self.lstm(seq.view(seq.shape[1],seq.shape[0],self.input_dim))
        return outputs, self.hidden
    
    def init_hidden(self, batch_size):
        return (torch.zeros(self.n_layers, batch_size, self.hid_dim),
                torch.zeros(self.n_layers, batch_size, self.hid_dim))
    
class Decoder(nn.Module):
    def __init__(self, input_dim, hid_dim, output_dim, n_layers=1):
        super(Decoder,self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.hid_dim = hid_dim
        self.n_layers = n_layers
        
        self.lstm = nn.LSTM(input_dim, hid_dim, n_layers, batch_first = False, bias=False)
        self.fc = nn.Linear(hid_dim, output_dim)
        
    def forward(self, x, encoder_hidden):
        lstm_out, self.hidden = self.lstm(x.unsqueeze(0), encoder_hidden)
        output = self.fc(lstm_out.squeeze(0))
        return output, self.hidden
    
class Seq2Seq(nn.Module):
    def __init__(self, input_dim, hid_dim, output_dim, ts_out, forcing = 1):
        super(Seq2Seq,self).__init__()
        self.output_dim = output_dim
        self.ts_out = ts_out
        self.encoder = Encoder(input_dim, hid_dim)
        self.decoder = Decoder(input_dim,hid_dim,output_dim)
        self.forcing = forcing

        
    def forward(self, source, y=None):
        batch_size = source.shape[0]
        target_len = self.ts_out
        outputs = torch.zeros(target_len, batch_size,self.output_dim)
        encoder_hidden = self.encoder.init_hidden(batch_size)
        encoder_output, encoder_hidden = self.encoder(source)
        
        decoder_input = source[:,-1,:]
        decoder_hidden = encoder_hidden
        
        for t in range(target_len):
            decoder_output, decoder_hidden = self.decoder(decoder_input, decoder_hidden)
            outputs[t] = decoder_output
            if (y is not None) and (t>1) and (torch.rand(1) < self.forcing):
                decoder_input = y[:,t].unsqueeze(1)
            else :
                decoder_input = decoder_output
        return outputs.squeeze().permute(1,0)
    
    
class LSTM(nn.Module):
    def __init__(self, input_size, output_size, time_step_in, time_step_out):
        super(LSTM, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.time_step_in = time_step_in
        self.time_step_out = time_step_out
        self.num_layers = 1
        
        self.encoder = nn.LSTM(self.input_size, self.output_size,
                               num_layers=self.num_layers, batch_first=True, bias=True)
        
        self.batch = nn.BatchNorm1d(self.output_size)
        self.linear2 = nn.Linear(self.num_layers*self.output_size, self.time_step_out)
        
    def forward(self,x):
        out_en, (h_en,_) = self.encoder(x)
        h_en = h_en.view(-1, self.num_layers*self.output_size)
        h_en = self.batch(h_en)
        out = nn.LeakyReLU()(h_en)
        #out = torch.sigmoid(self.linear(out))
        out = self.linear2(out)
        return out

# %% [markdown]
# # Parameters

# %%
myfloor = "Floor7Z1"
batch_size = 16
seq_len = 5

# %% [markdown]
# # Temp to AC

# %%
featureX = "temperature"
featureY = "ACPower"
resampleX_method = "max"
resampleY_method = "sum"
resampleX, scalersX, index_nan = createDTFeat(date1, date2, floor_dict, featureX,resample_method=resampleX_method)
resampleY, scalersY, index_nan = createDTFeat(date1, date2, floor_dict, featureY,resample_method=resampleY_method)
cleanedDataX, remain_date = cleanNan(resampleX, index_nan)
cleanedDataY, remain_date = cleanNan(resampleY, index_nan)

# %%
cutting_date = "2019-08-08"
train_date, test_date = splitDate(remain_date, cutting_date)
databyDateX = createDataByDate(cleanedDataX, featureX, remain_date)
databyDateY = createDataByDate(cleanedDataY, featureY, remain_date)
#getInfoDataByDate(databyDateX, train_date)
# Out:
# /var/folders/wm/ymsmhgr90dd6gyprvtgvcr080000gn/T/ipykernel_11992/1374678471.py:13: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   databyDate[date][floor] = np.asarray(datadict[floor][date][features])

# %%
loaderZtrain, loaderZval = LoaderXYtrain(databyDateX, databyDateY,myfloor,train_date, seq_len, batch_size, shuffle=True, val=True)
#loaderZtrain = LoaderXYtrain(databyDateX, databyDateY,myfloor,train_date, seq_len, batch_size, shuffle=True, val=False)
loaderZtest = LoaderByZoneXY(databyDateX, databyDateY, myfloor, test_date, seq_len, batch_size, shuffle=False)

# %%
def ModelTraining(model, optimizer, loss_fn ,dataloader,valloader,scheduler, epochs=100):
    seed_everything()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_loss = 1e3
    losses, mape, mae, validlosses, validmae = [], [], [], [], []
    loader = {"Train":dataloader, "Valid":valloader}
    for epoch in range(epochs):
        print('Epoch {}/{}'.format(epoch, epochs - 1))
        print('-' * 10)
        for phase in ["Train","Valid"]:
            if phase=="Train":
                model.train()
            else:
                model.eval()
                
            run_loss, run_mape, run_mae = 0., 0., 0.
            for data, label in loader[phase]:
                optimizer.zero_grad()
                #print("phase {} shape {}".format(phase, data.shape))
                with torch.set_grad_enabled(phase=="Train"):
                    output = model(data)
                    loss_val = loss_fn(output, label)
                    
                    if phase == "Train":
                        loss_val.backward()
                        optimizer.step()
                    
                run_loss += loss_val.item()*data.size(0)
                #run_mape += mean_absolute_percentage_error(label.detach().numpy(),output.detach().numpy())*data.size(0)
                run_mae  += mean_absolute_error(label.detach().numpy(),output.detach().numpy())*data.size(0)
            
            epoch_loss = run_loss/len(loader[phase])
            #epoch_mape = run_mape/len(dataloader)
            epoch_mae = run_mae/len(loader[phase])
            
            #print('{} Loss: {:.4f} MAE: {:.4f}'.format(phase, epoch_loss, epoch_mae))
            
            if phase=="Train":
                losses.append(epoch_loss)
                #mape.append(epoch_mape)
                mae.append(epoch_mae)
                #print("Epoch: {} Loss: {} Best Loss: {} MAPE: {} MAE: {}".format(epoch, epoch_loss, best_loss, epoch_mape, epoch_mae))
                
            elif phase == "Valid":
                validlosses.append(epoch_loss)
                validmae.append(epoch_mae)
                if epoch_loss < best_loss:
                    best_loss = epoch_loss
                    best_model_wts = copy.deepcopy(model.state_dict())
                    
            print('[{}]  Loss: {:.4f} MAE: {:.4f} Best : {:.4f}'.format(phase, epoch_loss, epoch_mae, best_loss))
                
            if scheduler is not None:
                scheduler.step()
        
    model.load_state_dict(best_model_wts)
    
    return model, losses, validlosses, mape, mae

# %%
loss_fn = nn.SmoothL1Loss()
modelLSTM = LSTM(1, 32, seq_len, seq_len)
modelSeq2Seq = Seq2Seq(1, 10, 1,seq_len)
optimizerAC = optim.Adam(modelLSTM.parameters(), lr=0.01)
scheduler = optim.lr_scheduler.StepLR(optimizerAC,step_size=10,gamma=0.1)

# %%
trainedAC, losses, validlosses, mape, mae = ModelTraining(modelLSTM, optimizerAC, loss_fn, loaderZtrain,loaderZval,scheduler,epochs=50)
# Out:
# Epoch 0/49
# ----------
# [Train]  Loss: 0.2382 MAE: 1.5910 Best : 1000.0000
# [Valid]  Loss: 0.9934 MAE: 4.3408 Best : 0.9934
# Epoch 1/49
# ----------
# [Train]  Loss: 0.1801 MAE: 1.2401 Best : 0.9934
# [Valid]  Loss: 0.1912 MAE: 1.5769 Best : 0.1912
# Epoch 2/49
# ----------
# [Train]  Loss: 0.1524 MAE: 1.1193 Best : 0.1912
# [Valid]  Loss: 0.3556 MAE: 2.8669 Best : 0.1912
# Epoch 3/49
# ----------
# [Train]  Loss: 0.1406 MAE: 1.1110 Best : 0.1912
# [Valid]  Loss: 0.1032 MAE: 0.9193 Best : 0.1032
# Epoch 4/49
# ----------
# [Train]  Loss: 0.1256 MAE: 1.0066 Best : 0.1032
# [Valid]  Loss: 0.1491 MAE: 1.5139 Best : 0.1032
# Epoch 5/49
# ----------
# [Train]  Loss: 0.1057 MAE: 0.7954 Best : 0.1032
# [Valid]  Loss: 0.0853 MAE: 0.6623 Best : 0.0853
# Epoch 6/49
# ----------
# [Train]  Loss: 0.1055 MAE: 0.8014 Best : 0.0853
# [Valid]  Loss: 0.0931 MAE: 0.8627 Best : 0.0853
# Epoch 7/49
# ----------
# [Train]  Loss: 0.1024 MAE: 0.7850 Best : 0.0853
# [Valid]  Loss: 0.0830 MAE: 0.5566 Best : 0.0830
# Epoch 8/49
# ----------
# [Train]  Loss: 0.1012 MAE: 0.7788 Best : 0.0830
# [Valid]  Loss: 0.0989 MAE: 1.0538 Best : 0.0830
# Epoch 9/49
# ----------
# [Train]  Loss: 0.1012 MAE: 0.7839 Best : 0.0830
# [Valid]  Loss: 0.0908 MAE: 0.9161 Best : 0.0830
# Epoch 10/49
# ----------
# [Train]  Loss: 0.0981 MAE: 0.7512 Best : 0.0830
# [Valid]  Loss: 0.0824 MAE: 0.6386 Best : 0.0824
# Epoch 11/49
# ----------
# [Train]  Loss: 0.0973 MAE: 0.7431 Best : 0.0824
# [Valid]  Loss: 0.0822 MAE: 0.6673 Best : 0.0822
# Epoch 12/49
# ----------
# [Train]  Loss: 0.0972 MAE: 0.7423 Best : 0.0822
# [Valid]  Loss: 0.0843 MAE: 0.6827 Best : 0.0822
# Epoch 13/49
# ----------
# [Train]  Loss: 0.0976 MAE: 0.7473 Best : 0.0822
# [Valid]  Loss: 0.0839 MAE: 0.6425 Best : 0.0822
# Epoch 14/49
# ----------
# [Train]  Loss: 0.0969 MAE: 0.7380 Best : 0.0822
# [Valid]  Loss: 0.0852 MAE: 0.6372 Best : 0.0822
# Epoch 15/49
# ----------
# [Train]  Loss: 0.0979 MAE: 0.7400 Best : 0.0822
# [Valid]  Loss: 0.0828 MAE: 0.6293 Best : 0.0822
# Epoch 16/49
# ----------
# [Train]  Loss: 0.0978 MAE: 0.7463 Best : 0.0822
# [Valid]  Loss: 0.0825 MAE: 0.6739 Best : 0.0822
# Epoch 17/49
# ----------
# [Train]  Loss: 0.0969 MAE: 0.7410 Best : 0.0822
# [Valid]  Loss: 0.0824 MAE: 0.6785 Best : 0.0822
# Epoch 18/49
# ----------
# [Train]  Loss: 0.0985 MAE: 0.7505 Best : 0.0822
# [Valid]  Loss: 0.0829 MAE: 0.6755 Best : 0.0822
# Epoch 19/49
# ----------
# [Train]  Loss: 0.0959 MAE: 0.7386 Best : 0.0822
# [Valid]  Loss: 0.0818 MAE: 0.6470 Best : 0.0818
# Epoch 20/49
# ----------
# [Train]  Loss: 0.0958 MAE: 0.7375 Best : 0.0818
# [Valid]  Loss: 0.0835 MAE: 0.6381 Best : 0.0818
# Epoch 21/49
# ----------
# [Train]  Loss: 0.0943 MAE: 0.7277 Best : 0.0818
# [Valid]  Loss: 0.0811 MAE: 0.6217 Best : 0.0811
# Epoch 22/49
# ----------
# [Train]  Loss: 0.0977 MAE: 0.7407 Best : 0.0811
# [Valid]  Loss: 0.0820 MAE: 0.6586 Best : 0.0811
# Epoch 23/49
# ----------
# [Train]  Loss: 0.0989 MAE: 0.7443 Best : 0.0811
# [Valid]  Loss: 0.0831 MAE: 0.6586 Best : 0.0811
# Epoch 24/49
# ----------
# [Train]  Loss: 0.0964 MAE: 0.7378 Best : 0.0811
# [Valid]  Loss: 0.0821 MAE: 0.6411 Best : 0.0811
# Epoch 25/49
# ----------
# [Train]  Loss: 0.0981 MAE: 0.7406 Best : 0.0811
# [Valid]  Loss: 0.0846 MAE: 0.7217 Best : 0.0811
# Epoch 26/49
# ----------
# [Train]  Loss: 0.0964 MAE: 0.7374 Best : 0.0811
# [Valid]  Loss: 0.0839 MAE: 0.6299 Best : 0.0811
# Epoch 27/49
# ----------
# [Train]  Loss: 0.0976 MAE: 0.7425 Best : 0.0811
# [Valid]  Loss: 0.0867 MAE: 0.7049 Best : 0.0811
# Epoch 28/49
# ----------
# [Train]  Loss: 0.0968 MAE: 0.7374 Best : 0.0811
# [Valid]  Loss: 0.0823 MAE: 0.6170 Best : 0.0811
# Epoch 29/49
# ----------
# [Train]  Loss: 0.0974 MAE: 0.7436 Best : 0.0811
# [Valid]  Loss: 0.0847 MAE: 0.5578 Best : 0.0811
# Epoch 30/49
# ----------
# [Train]  Loss: 0.0979 MAE: 0.7420 Best : 0.0811
# [Valid]  Loss: 0.0815 MAE: 0.5794 Best : 0.0811
# Epoch 31/49
# ----------
# [Train]  Loss: 0.0977 MAE: 0.7377 Best : 0.0811
# [Valid]  Loss: 0.0816 MAE: 0.6433 Best : 0.0811
# Epoch 32/49
# ----------
# [Train]  Loss: 0.0961 MAE: 0.7370 Best : 0.0811
# [Valid]  Loss: 0.0841 MAE: 0.6852 Best : 0.0811
# Epoch 33/49
# ----------
# [Train]  Loss: 0.0979 MAE: 0.7385 Best : 0.0811
# [Valid]  Loss: 0.0839 MAE: 0.6321 Best : 0.0811
# Epoch 34/49
# ----------
# [Train]  Loss: 0.0956 MAE: 0.7317 Best : 0.0811
# [Valid]  Loss: 0.0865 MAE: 0.6304 Best : 0.0811
# Epoch 35/49
# ----------
# [Train]  Loss: 0.0977 MAE: 0.7416 Best : 0.0811
# [Valid]  Loss: 0.0818 MAE: 0.6251 Best : 0.0811
# Epoch 36/49
# ----------
# [Train]  Loss: 0.0960 MAE: 0.7308 Best : 0.0811
# [Valid]  Loss: 0.0846 MAE: 0.6760 Best : 0.0811
# Epoch 37/49
# ----------
# [Train]  Loss: 0.0981 MAE: 0.7459 Best : 0.0811
# [Valid]  Loss: 0.0829 MAE: 0.6851 Best : 0.0811
# Epoch 38/49
# ----------
# [Train]  Loss: 0.0998 MAE: 0.7454 Best : 0.0811
# [Valid]  Loss: 0.0826 MAE: 0.6932 Best : 0.0811
# Epoch 39/49
# ----------
# [Train]  Loss: 0.0969 MAE: 0.7398 Best : 0.0811
# [Valid]  Loss: 0.0865 MAE: 0.6188 Best : 0.0811
# Epoch 40/49
# ----------
# [Train]  Loss: 0.0980 MAE: 0.7407 Best : 0.0811
# [Valid]  Loss: 0.0824 MAE: 0.6674 Best : 0.0811
# Epoch 41/49
# ----------
# [Train]  Loss: 0.0953 MAE: 0.7324 Best : 0.0811
# [Valid]  Loss: 0.0829 MAE: 0.6567 Best : 0.0811
# Epoch 42/49
# ----------
# [Train]  Loss: 0.0966 MAE: 0.7382 Best : 0.0811
# [Valid]  Loss: 0.0847 MAE: 0.5825 Best : 0.0811
# Epoch 43/49
# ----------
# [Train]  Loss: 0.0975 MAE: 0.7380 Best : 0.0811
# [Valid]  Loss: 0.0854 MAE: 0.6015 Best : 0.0811
# Epoch 44/49
# ----------
# [Train]  Loss: 0.0955 MAE: 0.7328 Best : 0.0811
# [Valid]  Loss: 0.0841 MAE: 0.6154 Best : 0.0811
# Epoch 45/49
# ----------
# [Train]  Loss: 0.0971 MAE: 0.7393 Best : 0.0811
# [Valid]  Loss: 0.0831 MAE: 0.6762 Best : 0.0811
# Epoch 46/49
# ----------
# [Train]  Loss: 0.0972 MAE: 0.7409 Best : 0.0811
# [Valid]  Loss: 0.0889 MAE: 0.6927 Best : 0.0811
# Epoch 47/49
# ----------
# [Train]  Loss: 0.0978 MAE: 0.7413 Best : 0.0811
# [Valid]  Loss: 0.0850 MAE: 0.7021 Best : 0.0811
# Epoch 48/49
# ----------
# [Train]  Loss: 0.0963 MAE: 0.7348 Best : 0.0811
# [Valid]  Loss: 0.0829 MAE: 0.6319 Best : 0.0811
# Epoch 49/49
# ----------
# [Train]  Loss: 0.0979 MAE: 0.7425 Best : 0.0811
# [Valid]  Loss: 0.0812 MAE: 0.5805 Best : 0.0811

# %%
plt.plot(losses)
plt.plot(validlosses)
#plt.yscale("log")

# %%
def ModelPrediction(model_to_test, date ,loader, lookahead):
    prediction = []
    true = []
    for val, valpred in loader[date]:
        model_to_test.eval()
        pred = model_to_test(val)
        #print(pred.shape)
        prediction.append(pred.detach().numpy())
        true.append(valpred.detach().numpy())
    pred_array = np.asarray(prediction)
    true_array = np.asarray(true)
    pred_shape = pred_array.shape
    flattenTrue = true_array.reshape(pred_shape[0]*pred_shape[1], lookahead)[::lookahead].flatten()
    flattenPred = pred_array.reshape(pred_shape[0]*pred_shape[1], lookahead)[::lookahead].flatten()
    return flattenTrue, flattenPred

def PredictionMultipleDate(model, dates, date_begin, date_end, loader, lookahead, scalers, zone_name, ft_idx):
    predictTrue = []
    predictPred = []
    valuePD = pd.DataFrame()
    idx_begin = dates.index(date_begin)
    idx_end = dates.index(date_end)
    for date in dates[idx_begin:idx_end]:
        true, pred = ModelPrediction(model, date, loader, lookahead)
        maxi = scalers[zone_name].data_max_[ft_idx]
        mini = scalers[zone_name].data_min_[ft_idx]
        true = true.reshape(-1,1)*(maxi-mini) + mini
        pred = pred.reshape(-1,1)*(maxi-mini) + mini
        array = np.concatenate([true, pred],axis=1)
        result = pd.DataFrame({"Truth": true.squeeze(),
                              "Prediction" : pred.squeeze()})
                              #"Date": pd.date_range(start=date,periods=true.shape[0], freq="5min")})
        valuePD = pd.concat((valuePD, result)).reset_index(drop=True)
    return valuePD

# %%
ft_idx = 0
may = [date for date in test_date if '2019-08' in date]
resultpd = PredictionMultipleDate(trainedAC,test_date,may[5], may[10],loaderZtest, seq_len, scalersY, myfloor, ft_idx)

# %%
resultpd[["Truth","Prediction"]].plot(figsize=(18,5))#,title="Model_"+str(indexroom))
# Out:
# <AxesSubplot:>

# %%
true, pred = ModelPrediction(trainedAC,"2019-08-23", loaderZtest, seq_len)

# %%
plt.plot(true)
plt.plot(pred)

# %%
torch.save(trainedAC.state_dict(), "./TempToACModel.pt")

# %% [markdown]
# # Lux To IlPower

# %%
featureLux = "lux"
featureIll = "lightPower"
resampleX_method = "max"
resampleY_method = "sum"
cutting_date = "2019-08-08"
#train_date, test_date = splitDate(remain_date, cutting_date)
databyDateLux = createDataByDate(cleanedDataX, featureLux, remain_date)
databyDateIll = createDataByDate(cleanedDataY, featureIll, remain_date)
#getInfoDataByDate(databyDateX, train_date)
# Out:
# /var/folders/wm/ymsmhgr90dd6gyprvtgvcr080000gn/T/ipykernel_11992/1374678471.py:13: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   databyDate[date][floor] = np.asarray(datadict[floor][date][features])

# %%
loaderLuxtrain, loaderLuxval = LoaderXYtrain(databyDateLux, databyDateIll,myfloor,train_date, seq_len, batch_size, shuffle=True, val=True)
#loaderZtrain = LoaderXYtrain(databyDateX, databyDateY,myfloor,train_date, seq_len, batch_size, shuffle=True, val=False)
loaderLuxtest = LoaderByZoneXY(databyDateLux, databyDateIll, myfloor, test_date, seq_len, batch_size, shuffle=False)

# %%
loss_fn = nn.SmoothL1Loss()
modelLux = LSTM(1, 32, seq_len, seq_len)
modelLuxSeq2Seq = Seq2Seq(1, 5, 1, 5)
optimizerLux = optim.Adam(modelLux.parameters(), lr=0.01)
schedulerLux = optim.lr_scheduler.StepLR(optimizerLux,step_size=10,gamma=0.1)

# %%
trainedLux, Luxlosses, Luxvalidlosses, Luxmape, Luxmae = ModelTraining(modelLux, optimizerLux, loss_fn, 
                                                                       loaderLuxtrain,loaderLuxval,schedulerLux,epochs=50)
# Out:
# Epoch 0/49
# ----------
# [Train]  Loss: 0.2417 MAE: 1.9927 Best : 1000.0000
# [Valid]  Loss: 0.1979 MAE: 1.7060 Best : 0.1979
# Epoch 1/49
# ----------
# [Train]  Loss: 0.2178 MAE: 1.8768 Best : 0.1979
# [Valid]  Loss: 0.2079 MAE: 1.7340 Best : 0.1979
# Epoch 2/49
# ----------
# [Train]  Loss: 0.2087 MAE: 1.7664 Best : 0.1979
# [Valid]  Loss: 0.1953 MAE: 1.8056 Best : 0.1953
# Epoch 3/49
# ----------
# [Train]  Loss: 0.2088 MAE: 1.7740 Best : 0.1953
# [Valid]  Loss: 0.1966 MAE: 1.7287 Best : 0.1953
# Epoch 4/49
# ----------
# [Train]  Loss: 0.2052 MAE: 1.7663 Best : 0.1953
# [Valid]  Loss: 0.1874 MAE: 1.7736 Best : 0.1874
# Epoch 5/49
# ----------
# [Train]  Loss: 0.1936 MAE: 1.6566 Best : 0.1874
# [Valid]  Loss: 0.1818 MAE: 1.5715 Best : 0.1818
# Epoch 6/49
# ----------
# [Train]  Loss: 0.1920 MAE: 1.6460 Best : 0.1818
# [Valid]  Loss: 0.1830 MAE: 1.5657 Best : 0.1818
# Epoch 7/49
# ----------
# [Train]  Loss: 0.1906 MAE: 1.6362 Best : 0.1818
# [Valid]  Loss: 0.1834 MAE: 1.5448 Best : 0.1818
# Epoch 8/49
# ----------
# [Train]  Loss: 0.1904 MAE: 1.6308 Best : 0.1818
# [Valid]  Loss: 0.1886 MAE: 1.5612 Best : 0.1818
# Epoch 9/49
# ----------
# [Train]  Loss: 0.1897 MAE: 1.6296 Best : 0.1818
# [Valid]  Loss: 0.1865 MAE: 1.6212 Best : 0.1818
# Epoch 10/49
# ----------
# [Train]  Loss: 0.1881 MAE: 1.6119 Best : 0.1818
# [Valid]  Loss: 0.1826 MAE: 1.5234 Best : 0.1818
# Epoch 11/49
# ----------
# [Train]  Loss: 0.1878 MAE: 1.6156 Best : 0.1818
# [Valid]  Loss: 0.1857 MAE: 1.4947 Best : 0.1818
# Epoch 12/49
# ----------
# [Train]  Loss: 0.1882 MAE: 1.6138 Best : 0.1818
# [Valid]  Loss: 0.1842 MAE: 1.5047 Best : 0.1818
# Epoch 13/49
# ----------
# [Train]  Loss: 0.1879 MAE: 1.6157 Best : 0.1818
# [Valid]  Loss: 0.1845 MAE: 1.4923 Best : 0.1818
# Epoch 14/49
# ----------
# [Train]  Loss: 0.1877 MAE: 1.6122 Best : 0.1818
# [Valid]  Loss: 0.1826 MAE: 1.5128 Best : 0.1818
# Epoch 15/49
# ----------
# [Train]  Loss: 0.1878 MAE: 1.6134 Best : 0.1818
# [Valid]  Loss: 0.1841 MAE: 1.5377 Best : 0.1818
# Epoch 16/49
# ----------
# [Train]  Loss: 0.1875 MAE: 1.6077 Best : 0.1818
# [Valid]  Loss: 0.1858 MAE: 1.5071 Best : 0.1818
# Epoch 17/49
# ----------
# [Train]  Loss: 0.1877 MAE: 1.6089 Best : 0.1818
# [Valid]  Loss: 0.1836 MAE: 1.5202 Best : 0.1818
# Epoch 18/49
# ----------
# [Train]  Loss: 0.1873 MAE: 1.6097 Best : 0.1818
# [Valid]  Loss: 0.1851 MAE: 1.5296 Best : 0.1818
# Epoch 19/49
# ----------
# [Train]  Loss: 0.1876 MAE: 1.6089 Best : 0.1818
# [Valid]  Loss: 0.1845 MAE: 1.5273 Best : 0.1818
# Epoch 20/49
# ----------
# [Train]  Loss: 0.1879 MAE: 1.6123 Best : 0.1818
# [Valid]  Loss: 0.1829 MAE: 1.5105 Best : 0.1818
# Epoch 21/49
# ----------
# [Train]  Loss: 0.1869 MAE: 1.6076 Best : 0.1818
# [Valid]  Loss: 0.1871 MAE: 1.5108 Best : 0.1818
# Epoch 22/49
# ----------
# [Train]  Loss: 0.1874 MAE: 1.6090 Best : 0.1818
# [Valid]  Loss: 0.1848 MAE: 1.5252 Best : 0.1818
# Epoch 23/49
# ----------
# [Train]  Loss: 0.1877 MAE: 1.6107 Best : 0.1818
# [Valid]  Loss: 0.1823 MAE: 1.4950 Best : 0.1818
# Epoch 24/49
# ----------
# [Train]  Loss: 0.1874 MAE: 1.6096 Best : 0.1818
# [Valid]  Loss: 0.1829 MAE: 1.5195 Best : 0.1818
# Epoch 25/49
# ----------
# [Train]  Loss: 0.1884 MAE: 1.6125 Best : 0.1818
# [Valid]  Loss: 0.1843 MAE: 1.5299 Best : 0.1818
# Epoch 26/49
# ----------
# [Train]  Loss: 0.1876 MAE: 1.6103 Best : 0.1818
# [Valid]  Loss: 0.1852 MAE: 1.5223 Best : 0.1818
# Epoch 27/49
# ----------
# [Train]  Loss: 0.1872 MAE: 1.6068 Best : 0.1818
# [Valid]  Loss: 0.1837 MAE: 1.5135 Best : 0.1818
# Epoch 28/49
# ----------
# [Train]  Loss: 0.1879 MAE: 1.6136 Best : 0.1818
# [Valid]  Loss: 0.1845 MAE: 1.5398 Best : 0.1818
# Epoch 29/49
# ----------
# [Train]  Loss: 0.1881 MAE: 1.6101 Best : 0.1818
# [Valid]  Loss: 0.1839 MAE: 1.5248 Best : 0.1818
# Epoch 30/49
# ----------
# [Train]  Loss: 0.1874 MAE: 1.6074 Best : 0.1818
# [Valid]  Loss: 0.1834 MAE: 1.5058 Best : 0.1818
# Epoch 31/49
# ----------
# [Train]  Loss: 0.1877 MAE: 1.6119 Best : 0.1818
# [Valid]  Loss: 0.1850 MAE: 1.5170 Best : 0.1818
# Epoch 32/49
# ----------
# [Train]  Loss: 0.1878 MAE: 1.6117 Best : 0.1818
# [Valid]  Loss: 0.1852 MAE: 1.5031 Best : 0.1818
# Epoch 33/49
# ----------
# [Train]  Loss: 0.1880 MAE: 1.6120 Best : 0.1818
# [Valid]  Loss: 0.1829 MAE: 1.5069 Best : 0.1818
# Epoch 34/49
# ----------
# [Train]  Loss: 0.1878 MAE: 1.6090 Best : 0.1818
# [Valid]  Loss: 0.1828 MAE: 1.5166 Best : 0.1818
# Epoch 35/49
# ----------
# [Train]  Loss: 0.1878 MAE: 1.6116 Best : 0.1818
# [Valid]  Loss: 0.1852 MAE: 1.5109 Best : 0.1818
# Epoch 36/49
# ----------
# [Train]  Loss: 0.1873 MAE: 1.6090 Best : 0.1818
# [Valid]  Loss: 0.1830 MAE: 1.4994 Best : 0.1818
# Epoch 37/49
# ----------
# [Train]  Loss: 0.1871 MAE: 1.6073 Best : 0.1818
# [Valid]  Loss: 0.1845 MAE: 1.5054 Best : 0.1818
# Epoch 38/49
# ----------
# [Train]  Loss: 0.1874 MAE: 1.6086 Best : 0.1818
# [Valid]  Loss: 0.1827 MAE: 1.5146 Best : 0.1818
# Epoch 39/49
# ----------
# [Train]  Loss: 0.1877 MAE: 1.6099 Best : 0.1818
# [Valid]  Loss: 0.1843 MAE: 1.4954 Best : 0.1818
# Epoch 40/49
# ----------
# [Train]  Loss: 0.1881 MAE: 1.6128 Best : 0.1818
# [Valid]  Loss: 0.1831 MAE: 1.5272 Best : 0.1818
# Epoch 41/49
# ----------
# [Train]  Loss: 0.1870 MAE: 1.6095 Best : 0.1818
# [Valid]  Loss: 0.1864 MAE: 1.5083 Best : 0.1818
# Epoch 42/49
# ----------
# [Train]  Loss: 0.1874 MAE: 1.6086 Best : 0.1818
# [Valid]  Loss: 0.1838 MAE: 1.5361 Best : 0.1818
# Epoch 43/49
# ----------
# [Train]  Loss: 0.1873 MAE: 1.6078 Best : 0.1818
# [Valid]  Loss: 0.1847 MAE: 1.5007 Best : 0.1818
# Epoch 44/49
# ----------
# [Train]  Loss: 0.1879 MAE: 1.6101 Best : 0.1818
# [Valid]  Loss: 0.1853 MAE: 1.5208 Best : 0.1818
# Epoch 45/49
# ----------
# [Train]  Loss: 0.1882 MAE: 1.6121 Best : 0.1818
# [Valid]  Loss: 0.1841 MAE: 1.5206 Best : 0.1818
# Epoch 46/49
# ----------
# [Train]  Loss: 0.1878 MAE: 1.6102 Best : 0.1818
# [Valid]  Loss: 0.1834 MAE: 1.5400 Best : 0.1818
# Epoch 47/49
# ----------
# [Train]  Loss: 0.1876 MAE: 1.6107 Best : 0.1818
# [Valid]  Loss: 0.1832 MAE: 1.5134 Best : 0.1818
# Epoch 48/49
# ----------
# [Train]  Loss: 0.1873 MAE: 1.6073 Best : 0.1818
# [Valid]  Loss: 0.1835 MAE: 1.5253 Best : 0.1818
# Epoch 49/49
# ----------
# [Train]  Loss: 0.1882 MAE: 1.6117 Best : 0.1818
# [Valid]  Loss: 0.1841 MAE: 1.5261 Best : 0.1818

# %%
plt.plot(Luxlosses)
plt.plot(Luxvalidlosses)
#plt.yscale("log")

# %%
ft_idx = 1
may = [date for date in test_date if '2019-08' in date]
resultpdLux = PredictionMultipleDate(trainedLux,test_date,may[5], may[10],loaderLuxtest, seq_len, scalersY, myfloor, ft_idx)

# %%
resultpdLux[["Truth","Prediction"]].plot(figsize=(18,5))#,title="Model_"+str(indexroom))
# Out:
# <AxesSubplot:>

# %%
torch.save(trainedLux.state_dict(), "./LuxToIllModel.pt")

# %% [markdown]
# # Concatenation Data

# %%
def concatTensor(x1, x2):
    return torch.cat([x1, x2],dim=-1)

def LoaderConcatData(loader1, loader2, model1, model2, batch_size=16, shuffle=True):
    dataX, dataY1, dataY2 = [], [], []
    model1.eval()
    model2.eval()
    for i,(data1, data2) in enumerate(zip(loader1, loader2)):
        x1,y1 = data1
        x2,y2 = data2
        intend1 = model1.encoder(x1)[1][0].detach()
        intend2 = model2.encoder(x2)[1][0].detach()
        shape1, shape2 = intend1.shape, intend2.shape
        intend1 = intend1.view(shape1[0]*shape1[1], -1)
        intend2 = intend2.view(shape2[0]*shape2[1], -1)
        concat = concatTensor(intend1, intend2)
        dataX.append(concat)
        dataY1.append(y1)
        dataY2.append(y2)
    
    myX, myY1, myY2= torch.stack(dataX), torch.stack(dataY1), torch.stack(dataY2)
    myX = myX.view(myX.size(0)*myX.size(1), -1)
    myY1 = myY1.view(myY1.size(0)*myY1.size(1),-1)
    myY2 = myY2.view(myY2.size(0)*myY2.size(1),-1)
    
    dataset1 = TensorDataset(myX, myY1)
    dataset2 = TensorDataset(myX, myY2)
    
    loaderfinal1 = DataLoader(dataset1, batch_size=batch_size, drop_last=True, shuffle=shuffle)
    loaderfinal2 = DataLoader(dataset2, batch_size=batch_size, drop_last=True, shuffle=shuffle)
    
    return loaderfinal1, loaderfinal2

def LoaderConcatbyDate(loader1, loader2, model1, model2, batch_size=16, shuffle=False):
    dates = list(loader1.keys())
    loaderY1 = {}
    loaderY2 = {}
    for date in dates:
        dataX, dataY1, dataY2 = [], [], []
        for i,(data1,data2) in enumerate(zip(loader1[date], loader2[date])):
            x1,y1 = data1
            x2,y2 = data2
            intend1 = model1.encoder(x1)[1][0].detach()
            intend2 = model2.encoder(x2)[1][0].detach()
            shape1, shape2 = intend1.shape, intend2.shape
            intend1 = intend1.view(shape1[0]*shape1[1], -1)
            intend2 = intend2.view(shape2[0]*shape2[1], -1)
            concat = concatTensor(intend1, intend2)
            dataX.append(concat)
            dataY1.append(y1)
            dataY2.append(y2)
    
        myX, myY1, myY2= torch.stack(dataX), torch.stack(dataY1), torch.stack(dataY2)
        myX = myX.view(myX.size(0)*myX.size(1), -1)
        myY1 = myY1.view(myY1.size(0)*myY1.size(1),-1)
        myY2 = myY2.view(myY2.size(0)*myY2.size(1),-1)

        dataset1 = TensorDataset(myX, myY1)
        dataset2 = TensorDataset(myX, myY2)

        loaderfinal1 = DataLoader(dataset1, batch_size=batch_size, drop_last=True, shuffle=shuffle)
        loaderfinal2 = DataLoader(dataset2, batch_size=batch_size, drop_last=True, shuffle=shuffle)
        
        loaderY1[date] = loaderfinal1
        loaderY2[date] = loaderfinal2
    return loaderY1, loaderY2


def LoaderConcat(dataX, dataY):
    myX = dataX.view(dataX.size(0)*dataX.size(1), -1)
    myY = dataY.view(dataY.size(0)*dataY.size(1), -1)
    mydataset = TensorDataset(myX, myY)
    loader = DataLoader(mydataset, batch_size=16, drop_last=True, shuffle=True)
    return loader

# %%
loaderEACtrain, loaderEIlltrain = LoaderConcatData(loaderZtrain, loaderLuxtrain, trainedAC, trainedLux)
loaderEACval, loaderEIllval = LoaderConcatData(loaderZval, loaderLuxval, trainedAC, trainedLux)

# %%
loaderEACtest, loaderEIlltest = LoaderConcatbyDate(loaderZtest, loaderLuxtest, trainedAC, trainedLux)

# %%
class Linear(nn.Module):
    def __init__(self, nb_units, input_dim, output_dim):
        super(Linear, self).__init__()
        
        self.nb_units = nb_units
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.nb_units2 = 16
    
        self.fc1 = nn.Linear(input_dim, nb_units)
        self.fc2 = nn.Linear(nb_units, self.nb_units2)
        self.fc3 = nn.Linear(self.nb_units2, output_dim)
        
        self.batch1 = nn.BatchNorm1d(nb_units)
        self.batch2 = nn.BatchNorm1d(self.nb_units2)
        #self.drop = nn.Dropout(0.2)
        
    def forward(self, x):
        inputs = x.squeeze(-1)
        out = self.fc1(inputs)
        out = nn.LeakyReLU()(out)
        out = self.batch1(out)
        
        out = nn.LeakyReLU()(self.fc2(out))
        out = self.batch2(out)
        
        out = self.fc3(out)
        return out

# %%
x,y = iter(loaderEACtrain).next()

# %%
x.shape
# Out:
# torch.Size([16, 64])

# %%
PowerPredictorAC = Linear(32,64, 5)
optPPLAC = optim.Adam(PowerPredictorAC.parameters(), lr=0.01)
schePPLAC = optim.lr_scheduler.StepLR(optPPLAC,step_size=10,gamma=0.1)

# %%
modelPPLAC, pplAClosses, pplACvalidlosses, pplACmape, pplACmae = ModelTraining(PowerPredictorAC, optPPLAC, loss_fn, 
                                                                       loaderEACtrain,loaderEACval,schePPLAC,epochs=100)
# Out:
# Epoch 0/99
# ----------
# [Train]  Loss: 0.2358 MAE: 1.8576 Best : 1000.0000
# [Valid]  Loss: 0.1346 MAE: 1.1746 Best : 0.1346
# Epoch 1/99
# ----------
# [Train]  Loss: 0.2105 MAE: 1.7959 Best : 0.1346
# [Valid]  Loss: 0.1254 MAE: 1.1252 Best : 0.1254
# Epoch 2/99
# ----------
# [Train]  Loss: 0.2019 MAE: 1.7584 Best : 0.1254
# [Valid]  Loss: 0.1134 MAE: 0.9995 Best : 0.1134
# Epoch 3/99
# ----------
# [Train]  Loss: 0.1928 MAE: 1.7177 Best : 0.1134
# [Valid]  Loss: 0.1245 MAE: 1.1604 Best : 0.1134
# Epoch 4/99
# ----------
# [Train]  Loss: 0.1886 MAE: 1.6891 Best : 0.1134
# [Valid]  Loss: 0.1165 MAE: 1.0414 Best : 0.1134
# Epoch 5/99
# ----------
# [Train]  Loss: 0.1764 MAE: 1.6226 Best : 0.1134
# [Valid]  Loss: 0.1001 MAE: 0.8624 Best : 0.1001
# Epoch 6/99
# ----------
# [Train]  Loss: 0.1714 MAE: 1.6122 Best : 0.1001
# [Valid]  Loss: 0.1008 MAE: 0.8761 Best : 0.1001
# Epoch 7/99
# ----------
# [Train]  Loss: 0.1700 MAE: 1.6025 Best : 0.1001
# [Valid]  Loss: 0.1051 MAE: 0.9815 Best : 0.1001
# Epoch 8/99
# ----------
# [Train]  Loss: 0.1779 MAE: 1.6597 Best : 0.1001
# [Valid]  Loss: 0.1185 MAE: 1.2413 Best : 0.1001
# Epoch 9/99
# ----------
# [Train]  Loss: 0.1668 MAE: 1.5836 Best : 0.1001
# [Valid]  Loss: 0.1167 MAE: 1.0641 Best : 0.1001
# Epoch 10/99
# ----------
# [Train]  Loss: 0.1706 MAE: 1.6057 Best : 0.1001
# [Valid]  Loss: 0.0974 MAE: 0.8224 Best : 0.0974
# Epoch 11/99
# ----------
# [Train]  Loss: 0.1701 MAE: 1.6056 Best : 0.0974
# [Valid]  Loss: 0.0983 MAE: 0.9065 Best : 0.0974
# Epoch 12/99
# ----------
# [Train]  Loss: 0.1663 MAE: 1.5815 Best : 0.0974
# [Valid]  Loss: 0.0988 MAE: 0.8742 Best : 0.0974
# Epoch 13/99
# ----------
# [Train]  Loss: 0.1690 MAE: 1.5821 Best : 0.0974
# [Valid]  Loss: 0.0972 MAE: 0.9113 Best : 0.0972
# Epoch 14/99
# ----------
# [Train]  Loss: 0.1617 MAE: 1.5425 Best : 0.0972
# [Valid]  Loss: 0.0984 MAE: 0.8586 Best : 0.0972
# Epoch 15/99
# ----------
# [Train]  Loss: 0.1669 MAE: 1.5849 Best : 0.0972
# [Valid]  Loss: 0.0967 MAE: 0.8628 Best : 0.0967
# Epoch 16/99
# ----------
# [Train]  Loss: 0.1655 MAE: 1.5670 Best : 0.0967
# [Valid]  Loss: 0.0984 MAE: 0.8481 Best : 0.0967
# Epoch 17/99
# ----------
# [Train]  Loss: 0.1648 MAE: 1.5698 Best : 0.0967
# [Valid]  Loss: 0.1005 MAE: 0.9082 Best : 0.0967
# Epoch 18/99
# ----------
# [Train]  Loss: 0.1666 MAE: 1.5805 Best : 0.0967
# [Valid]  Loss: 0.0942 MAE: 0.8104 Best : 0.0942
# Epoch 19/99
# ----------
# [Train]  Loss: 0.1674 MAE: 1.5840 Best : 0.0942
# [Valid]  Loss: 0.1027 MAE: 0.9347 Best : 0.0942
# Epoch 20/99
# ----------
# [Train]  Loss: 0.1705 MAE: 1.6054 Best : 0.0942
# [Valid]  Loss: 0.1039 MAE: 1.0909 Best : 0.0942
# Epoch 21/99
# ----------
# [Train]  Loss: 0.1666 MAE: 1.5730 Best : 0.0942
# [Valid]  Loss: 0.1092 MAE: 1.0555 Best : 0.0942
# Epoch 22/99
# ----------
# [Train]  Loss: 0.1675 MAE: 1.5897 Best : 0.0942
# [Valid]  Loss: 0.0957 MAE: 0.8366 Best : 0.0942
# Epoch 23/99
# ----------
# [Train]  Loss: 0.1645 MAE: 1.5705 Best : 0.0942
# [Valid]  Loss: 0.1005 MAE: 1.0226 Best : 0.0942
# Epoch 24/99
# ----------
# [Train]  Loss: 0.1652 MAE: 1.5761 Best : 0.0942
# [Valid]  Loss: 0.1079 MAE: 1.0289 Best : 0.0942
# Epoch 25/99
# ----------
# [Train]  Loss: 0.1656 MAE: 1.5801 Best : 0.0942
# [Valid]  Loss: 0.1028 MAE: 1.0659 Best : 0.0942
# Epoch 26/99
# ----------
# [Train]  Loss: 0.1658 MAE: 1.5742 Best : 0.0942
# [Valid]  Loss: 0.0984 MAE: 0.9544 Best : 0.0942
# Epoch 27/99
# ----------
# [Train]  Loss: 0.1711 MAE: 1.5995 Best : 0.0942
# [Valid]  Loss: 0.0985 MAE: 0.9069 Best : 0.0942
# Epoch 28/99
# ----------
# [Train]  Loss: 0.1653 MAE: 1.5804 Best : 0.0942
# [Valid]  Loss: 0.1079 MAE: 1.0564 Best : 0.0942
# Epoch 29/99
# ----------
# [Train]  Loss: 0.1670 MAE: 1.5801 Best : 0.0942
# [Valid]  Loss: 0.1002 MAE: 1.0081 Best : 0.0942
# Epoch 30/99
# ----------
# [Train]  Loss: 0.1656 MAE: 1.5665 Best : 0.0942
# [Valid]  Loss: 0.1020 MAE: 0.9197 Best : 0.0942
# Epoch 31/99
# ----------
# [Train]  Loss: 0.1686 MAE: 1.5920 Best : 0.0942
# [Valid]  Loss: 0.1057 MAE: 1.0461 Best : 0.0942
# Epoch 32/99
# ----------
# [Train]  Loss: 0.1688 MAE: 1.6035 Best : 0.0942
# [Valid]  Loss: 0.1073 MAE: 1.0335 Best : 0.0942
# Epoch 33/99
# ----------
# [Train]  Loss: 0.1660 MAE: 1.5765 Best : 0.0942
# [Valid]  Loss: 0.0992 MAE: 0.8876 Best : 0.0942
# Epoch 34/99
# ----------
# [Train]  Loss: 0.1662 MAE: 1.5832 Best : 0.0942
# [Valid]  Loss: 0.0987 MAE: 0.8486 Best : 0.0942
# Epoch 35/99
# ----------
# [Train]  Loss: 0.1655 MAE: 1.5830 Best : 0.0942
# [Valid]  Loss: 0.0994 MAE: 0.8611 Best : 0.0942
# Epoch 36/99
# ----------
# [Train]  Loss: 0.1649 MAE: 1.5728 Best : 0.0942
# [Valid]  Loss: 0.0982 MAE: 0.9070 Best : 0.0942
# Epoch 37/99
# ----------
# [Train]  Loss: 0.1676 MAE: 1.5908 Best : 0.0942
# [Valid]  Loss: 0.0955 MAE: 0.8280 Best : 0.0942
# Epoch 38/99
# ----------
# [Train]  Loss: 0.1657 MAE: 1.5850 Best : 0.0942
# [Valid]  Loss: 0.0992 MAE: 0.8713 Best : 0.0942
# Epoch 39/99
# ----------
# [Train]  Loss: 0.1679 MAE: 1.5913 Best : 0.0942
# [Valid]  Loss: 0.1052 MAE: 0.9515 Best : 0.0942
# Epoch 40/99
# ----------
# [Train]  Loss: 0.1690 MAE: 1.6003 Best : 0.0942
# [Valid]  Loss: 0.0981 MAE: 0.9339 Best : 0.0942
# Epoch 41/99
# ----------
# [Train]  Loss: 0.1673 MAE: 1.5892 Best : 0.0942
# [Valid]  Loss: 0.0979 MAE: 0.8998 Best : 0.0942
# Epoch 42/99
# ----------
# [Train]  Loss: 0.1648 MAE: 1.5775 Best : 0.0942
# [Valid]  Loss: 0.0973 MAE: 0.9215 Best : 0.0942
# Epoch 43/99
# ----------
# [Train]  Loss: 0.1697 MAE: 1.6150 Best : 0.0942
# [Valid]  Loss: 0.1004 MAE: 0.8902 Best : 0.0942
# Epoch 44/99
# ----------
# [Train]  Loss: 0.1712 MAE: 1.6152 Best : 0.0942
# [Valid]  Loss: 0.0950 MAE: 0.8484 Best : 0.0942
# Epoch 45/99
# ----------
# [Train]  Loss: 0.1635 MAE: 1.5545 Best : 0.0942
# [Valid]  Loss: 0.0957 MAE: 0.8167 Best : 0.0942
# Epoch 46/99
# ----------
# [Train]  Loss: 0.1647 MAE: 1.5615 Best : 0.0942
# [Valid]  Loss: 0.1110 MAE: 1.0650 Best : 0.0942
# Epoch 47/99
# ----------
# [Train]  Loss: 0.1660 MAE: 1.5730 Best : 0.0942
# [Valid]  Loss: 0.0975 MAE: 0.8323 Best : 0.0942
# Epoch 48/99
# ----------
# [Train]  Loss: 0.1713 MAE: 1.5959 Best : 0.0942
# [Valid]  Loss: 0.0957 MAE: 0.8406 Best : 0.0942
# Epoch 49/99
# ----------
# [Train]  Loss: 0.1677 MAE: 1.5889 Best : 0.0942
# [Valid]  Loss: 0.0991 MAE: 0.9857 Best : 0.0942
# Epoch 50/99
# ----------
# [Train]  Loss: 0.1676 MAE: 1.5868 Best : 0.0942
# [Valid]  Loss: 0.1018 MAE: 0.9114 Best : 0.0942
# Epoch 51/99
# ----------
# [Train]  Loss: 0.1654 MAE: 1.5761 Best : 0.0942
# [Valid]  Loss: 0.1104 MAE: 1.0559 Best : 0.0942
# Epoch 52/99
# ----------
# [Train]  Loss: 0.1646 MAE: 1.5719 Best : 0.0942
# [Valid]  Loss: 0.1033 MAE: 0.9380 Best : 0.0942
# Epoch 53/99
# ----------
# [Train]  Loss: 0.1691 MAE: 1.5998 Best : 0.0942
# [Valid]  Loss: 0.0971 MAE: 0.9123 Best : 0.0942
# Epoch 54/99
# ----------
# [Train]  Loss: 0.1661 MAE: 1.5728 Best : 0.0942
# [Valid]  Loss: 0.0975 MAE: 0.8522 Best : 0.0942
# Epoch 55/99
# ----------
# [Train]  Loss: 0.1658 MAE: 1.5770 Best : 0.0942
# [Valid]  Loss: 0.0978 MAE: 0.8664 Best : 0.0942
# Epoch 56/99
# ----------
# [Train]  Loss: 0.1686 MAE: 1.5971 Best : 0.0942
# [Valid]  Loss: 0.1032 MAE: 0.9576 Best : 0.0942
# Epoch 57/99
# ----------
# [Train]  Loss: 0.1652 MAE: 1.5687 Best : 0.0942
# [Valid]  Loss: 0.0987 MAE: 0.8532 Best : 0.0942
# Epoch 58/99
# ----------
# [Train]  Loss: 0.1640 MAE: 1.5739 Best : 0.0942
# [Valid]  Loss: 0.1148 MAE: 1.1827 Best : 0.0942
# Epoch 59/99
# ----------
# [Train]  Loss: 0.1667 MAE: 1.5860 Best : 0.0942
# [Valid]  Loss: 0.0964 MAE: 0.8573 Best : 0.0942
# Epoch 60/99
# ----------
# [Train]  Loss: 0.1648 MAE: 1.5720 Best : 0.0942
# [Valid]  Loss: 0.1063 MAE: 0.9479 Best : 0.0942
# Epoch 61/99
# ----------
# [Train]  Loss: 0.1667 MAE: 1.5758 Best : 0.0942
# [Valid]  Loss: 0.0982 MAE: 0.8707 Best : 0.0942
# Epoch 62/99
# ----------
# [Train]  Loss: 0.1715 MAE: 1.6147 Best : 0.0942
# [Valid]  Loss: 0.0951 MAE: 0.7789 Best : 0.0942
# Epoch 63/99
# ----------
# [Train]  Loss: 0.1664 MAE: 1.5902 Best : 0.0942
# [Valid]  Loss: 0.1077 MAE: 1.0343 Best : 0.0942
# Epoch 64/99
# ----------
# [Train]  Loss: 0.1697 MAE: 1.6015 Best : 0.0942
# [Valid]  Loss: 0.1031 MAE: 0.9512 Best : 0.0942
# Epoch 65/99
# ----------
# [Train]  Loss: 0.1655 MAE: 1.5749 Best : 0.0942
# [Valid]  Loss: 0.0992 MAE: 0.8569 Best : 0.0942
# Epoch 66/99
# ----------
# [Train]  Loss: 0.1663 MAE: 1.5887 Best : 0.0942
# [Valid]  Loss: 0.1035 MAE: 0.9080 Best : 0.0942
# Epoch 67/99
# ----------
# [Train]  Loss: 0.1605 MAE: 1.5468 Best : 0.0942
# [Valid]  Loss: 0.1057 MAE: 0.9788 Best : 0.0942
# Epoch 68/99
# ----------
# [Train]  Loss: 0.1644 MAE: 1.5704 Best : 0.0942
# [Valid]  Loss: 0.0951 MAE: 0.8432 Best : 0.0942
# Epoch 69/99
# ----------
# [Train]  Loss: 0.1692 MAE: 1.5858 Best : 0.0942
# [Valid]  Loss: 0.0936 MAE: 0.7916 Best : 0.0936
# Epoch 70/99
# ----------
# [Train]  Loss: 0.1663 MAE: 1.5892 Best : 0.0936
# [Valid]  Loss: 0.1093 MAE: 1.0883 Best : 0.0936
# Epoch 71/99
# ----------
# [Train]  Loss: 0.1653 MAE: 1.5736 Best : 0.0936
# [Valid]  Loss: 0.0991 MAE: 0.8583 Best : 0.0936
# Epoch 72/99
# ----------
# [Train]  Loss: 0.1647 MAE: 1.5656 Best : 0.0936
# [Valid]  Loss: 0.0980 MAE: 0.9258 Best : 0.0936
# Epoch 73/99
# ----------
# [Train]  Loss: 0.1679 MAE: 1.5974 Best : 0.0936
# [Valid]  Loss: 0.1105 MAE: 0.9921 Best : 0.0936
# Epoch 74/99
# ----------
# [Train]  Loss: 0.1669 MAE: 1.5760 Best : 0.0936
# [Valid]  Loss: 0.0976 MAE: 0.8442 Best : 0.0936
# Epoch 75/99
# ----------
# [Train]  Loss: 0.1668 MAE: 1.5895 Best : 0.0936
# [Valid]  Loss: 0.0971 MAE: 0.9215 Best : 0.0936
# Epoch 76/99
# ----------
# [Train]  Loss: 0.1676 MAE: 1.5891 Best : 0.0936
# [Valid]  Loss: 0.0975 MAE: 0.8248 Best : 0.0936
# Epoch 77/99
# ----------
# [Train]  Loss: 0.1661 MAE: 1.5909 Best : 0.0936
# [Valid]  Loss: 0.0963 MAE: 0.8469 Best : 0.0936
# Epoch 78/99
# ----------
# [Train]  Loss: 0.1665 MAE: 1.5858 Best : 0.0936
# [Valid]  Loss: 0.0987 MAE: 0.9031 Best : 0.0936
# Epoch 79/99
# ----------
# [Train]  Loss: 0.1639 MAE: 1.5580 Best : 0.0936
# [Valid]  Loss: 0.1181 MAE: 1.2018 Best : 0.0936
# Epoch 80/99
# ----------
# [Train]  Loss: 0.1657 MAE: 1.5776 Best : 0.0936
# [Valid]  Loss: 0.0977 MAE: 0.8527 Best : 0.0936
# Epoch 81/99
# ----------
# [Train]  Loss: 0.1695 MAE: 1.6079 Best : 0.0936
# [Valid]  Loss: 0.1024 MAE: 0.9230 Best : 0.0936
# Epoch 82/99
# ----------
# [Train]  Loss: 0.1637 MAE: 1.5543 Best : 0.0936
# [Valid]  Loss: 0.0970 MAE: 0.8318 Best : 0.0936
# Epoch 83/99
# ----------
# [Train]  Loss: 0.1699 MAE: 1.5999 Best : 0.0936
# [Valid]  Loss: 0.1028 MAE: 0.9112 Best : 0.0936
# Epoch 84/99
# ----------
# [Train]  Loss: 0.1690 MAE: 1.5892 Best : 0.0936
# [Valid]  Loss: 0.1296 MAE: 1.3164 Best : 0.0936
# Epoch 85/99
# ----------
# [Train]  Loss: 0.1643 MAE: 1.5621 Best : 0.0936
# [Valid]  Loss: 0.0964 MAE: 0.8312 Best : 0.0936
# Epoch 86/99
# ----------
# [Train]  Loss: 0.1674 MAE: 1.5834 Best : 0.0936
# [Valid]  Loss: 0.0982 MAE: 0.8234 Best : 0.0936
# Epoch 87/99
# ----------
# [Train]  Loss: 0.1636 MAE: 1.5619 Best : 0.0936
# [Valid]  Loss: 0.1074 MAE: 0.9935 Best : 0.0936
# Epoch 88/99
# ----------
# [Train]  Loss: 0.1679 MAE: 1.5976 Best : 0.0936
# [Valid]  Loss: 0.0993 MAE: 0.9720 Best : 0.0936
# Epoch 89/99
# ----------
# [Train]  Loss: 0.1630 MAE: 1.5514 Best : 0.0936
# [Valid]  Loss: 0.0978 MAE: 0.9290 Best : 0.0936
# Epoch 90/99
# ----------
# [Train]  Loss: 0.1657 MAE: 1.5733 Best : 0.0936
# [Valid]  Loss: 0.0985 MAE: 0.9291 Best : 0.0936
# Epoch 91/99
# ----------
# [Train]  Loss: 0.1643 MAE: 1.5718 Best : 0.0936
# [Valid]  Loss: 0.0957 MAE: 0.8136 Best : 0.0936
# Epoch 92/99
# ----------
# [Train]  Loss: 0.1666 MAE: 1.5798 Best : 0.0936
# [Valid]  Loss: 0.0966 MAE: 0.8565 Best : 0.0936
# Epoch 93/99
# ----------
# [Train]  Loss: 0.1681 MAE: 1.6003 Best : 0.0936
# [Valid]  Loss: 0.1032 MAE: 1.0163 Best : 0.0936
# Epoch 94/99
# ----------
# [Train]  Loss: 0.1667 MAE: 1.5705 Best : 0.0936
# [Valid]  Loss: 0.0948 MAE: 0.8160 Best : 0.0936
# Epoch 95/99
# ----------
# [Train]  Loss: 0.1692 MAE: 1.5876 Best : 0.0936
# [Valid]  Loss: 0.0995 MAE: 0.9492 Best : 0.0936
# Epoch 96/99
# ----------
# [Train]  Loss: 0.1687 MAE: 1.5866 Best : 0.0936
# [Valid]  Loss: 0.1004 MAE: 0.9032 Best : 0.0936
# Epoch 97/99
# ----------
# [Train]  Loss: 0.1687 MAE: 1.5927 Best : 0.0936
# [Valid]  Loss: 0.0991 MAE: 0.9789 Best : 0.0936
# Epoch 98/99
# ----------
# [Train]  Loss: 0.1650 MAE: 1.5707 Best : 0.0936
# [Valid]  Loss: 0.0989 MAE: 0.8508 Best : 0.0936
# Epoch 99/99
# ----------
# [Train]  Loss: 0.1667 MAE: 1.5772 Best : 0.0936
# [Valid]  Loss: 0.1017 MAE: 0.9086 Best : 0.0936

# %%
plt.plot(pplAClosses)
plt.plot(pplACvalidlosses)

# %%
ft_idx = 0
may = [date for date in test_date if '2019-08' in date]
i1, i2 = 10, 15
resultpdEAC = PredictionMultipleDate(modelPPLAC,test_date,may[i1], may[i2],loaderEACtest, seq_len, scalersY, myfloor, ft_idx)
resultpd = PredictionMultipleDate(trainedAC,test_date,may[i1], may[i2],loaderZtest, seq_len, scalersY, myfloor, ft_idx)

# %%
modelPPLAC
# Out:
# Linear(
#   (fc1): Linear(in_features=64, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=5, bias=True)
#   (batch1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (batch2): BatchNorm1d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
resultpdEAC[["Truth","Prediction"]].plot(figsize=(18,5))#,title="Model_"+str(indexroom))
resultpd[["Truth","Prediction"]].plot(figsize=(18,5))#,title="Model_"+str(indexroom))
# Out:
# <AxesSubplot:>

# %%
torch.save(modelPPLAC.state_dict(), "./PPLAC.pt")

# %%
PowerPredictorIll = Linear(32,64, 5)
optPPLIll = optim.Adam(PowerPredictorIll.parameters(), lr=0.01)
schePPLIll = optim.lr_scheduler.StepLR(optPPLIll,step_size=10,gamma=0.1)

# %%
modelPPLIll, pplIlllosses, pplIllvalidlosses, pplIllmape, pplIllmae = ModelTraining(PowerPredictorIll, optPPLIll, loss_fn, 
                                                                       loaderEIlltrain,loaderEIllval,schePPLIll,epochs=100)
# Out:
# Epoch 0/99
# ----------
# [Train]  Loss: 0.2453 MAE: 2.0471 Best : 1000.0000
# [Valid]  Loss: 0.1854 MAE: 1.6501 Best : 0.1854
# Epoch 1/99
# ----------
# [Train]  Loss: 0.2282 MAE: 1.9816 Best : 0.1854
# [Valid]  Loss: 0.1855 MAE: 1.6027 Best : 0.1854
# Epoch 2/99
# ----------
# [Train]  Loss: 0.2271 MAE: 1.9853 Best : 0.1854
# [Valid]  Loss: 0.1985 MAE: 1.7465 Best : 0.1854
# Epoch 3/99
# ----------
# [Train]  Loss: 0.2270 MAE: 1.9774 Best : 0.1854
# [Valid]  Loss: 0.1866 MAE: 1.6650 Best : 0.1854
# Epoch 4/99
# ----------
# [Train]  Loss: 0.2272 MAE: 1.9805 Best : 0.1854
# [Valid]  Loss: 0.1873 MAE: 1.6078 Best : 0.1854
# Epoch 5/99
# ----------
# [Train]  Loss: 0.2146 MAE: 1.8980 Best : 0.1854
# [Valid]  Loss: 0.1861 MAE: 1.6912 Best : 0.1854
# Epoch 6/99
# ----------
# [Train]  Loss: 0.2167 MAE: 1.9278 Best : 0.1854
# [Valid]  Loss: 0.1881 MAE: 1.7658 Best : 0.1854
# Epoch 7/99
# ----------
# [Train]  Loss: 0.2138 MAE: 1.9059 Best : 0.1854
# [Valid]  Loss: 0.1879 MAE: 1.6914 Best : 0.1854
# Epoch 8/99
# ----------
# [Train]  Loss: 0.2152 MAE: 1.9199 Best : 0.1854
# [Valid]  Loss: 0.1868 MAE: 1.7527 Best : 0.1854
# Epoch 9/99
# ----------
# [Train]  Loss: 0.2168 MAE: 1.9272 Best : 0.1854
# [Valid]  Loss: 0.1839 MAE: 1.6200 Best : 0.1839
# Epoch 10/99
# ----------
# [Train]  Loss: 0.2158 MAE: 1.9220 Best : 0.1839
# [Valid]  Loss: 0.1866 MAE: 1.7481 Best : 0.1839
# Epoch 11/99
# ----------
# [Train]  Loss: 0.2150 MAE: 1.9195 Best : 0.1839
# [Valid]  Loss: 0.1854 MAE: 1.6655 Best : 0.1839
# Epoch 12/99
# ----------
# [Train]  Loss: 0.2135 MAE: 1.9083 Best : 0.1839
# [Valid]  Loss: 0.1853 MAE: 1.7242 Best : 0.1839
# Epoch 13/99
# ----------
# [Train]  Loss: 0.2146 MAE: 1.9133 Best : 0.1839
# [Valid]  Loss: 0.1873 MAE: 1.6794 Best : 0.1839
# Epoch 14/99
# ----------
# [Train]  Loss: 0.2153 MAE: 1.9216 Best : 0.1839
# [Valid]  Loss: 0.1868 MAE: 1.6265 Best : 0.1839
# Epoch 15/99
# ----------
# [Train]  Loss: 0.2128 MAE: 1.9137 Best : 0.1839
# [Valid]  Loss: 0.1865 MAE: 1.7557 Best : 0.1839
# Epoch 16/99
# ----------
# [Train]  Loss: 0.2127 MAE: 1.9165 Best : 0.1839
# [Valid]  Loss: 0.1868 MAE: 1.7467 Best : 0.1839
# Epoch 17/99
# ----------
# [Train]  Loss: 0.2146 MAE: 1.9156 Best : 0.1839
# [Valid]  Loss: 0.1880 MAE: 1.6009 Best : 0.1839
# Epoch 18/99
# ----------
# [Train]  Loss: 0.2145 MAE: 1.9152 Best : 0.1839
# [Valid]  Loss: 0.1854 MAE: 1.6750 Best : 0.1839
# Epoch 19/99
# ----------
# [Train]  Loss: 0.2121 MAE: 1.9005 Best : 0.1839
# [Valid]  Loss: 0.1862 MAE: 1.6679 Best : 0.1839
# Epoch 20/99
# ----------
# [Train]  Loss: 0.2122 MAE: 1.9031 Best : 0.1839
# [Valid]  Loss: 0.1866 MAE: 1.7530 Best : 0.1839
# Epoch 21/99
# ----------
# [Train]  Loss: 0.2158 MAE: 1.9280 Best : 0.1839
# [Valid]  Loss: 0.1858 MAE: 1.7246 Best : 0.1839
# Epoch 22/99
# ----------
# [Train]  Loss: 0.2161 MAE: 1.9243 Best : 0.1839
# [Valid]  Loss: 0.1857 MAE: 1.6363 Best : 0.1839
# Epoch 23/99
# ----------
# [Train]  Loss: 0.2141 MAE: 1.9174 Best : 0.1839
# [Valid]  Loss: 0.1862 MAE: 1.7176 Best : 0.1839
# Epoch 24/99
# ----------
# [Train]  Loss: 0.2146 MAE: 1.9168 Best : 0.1839
# [Valid]  Loss: 0.1855 MAE: 1.6811 Best : 0.1839
# Epoch 25/99
# ----------
# [Train]  Loss: 0.2155 MAE: 1.9217 Best : 0.1839
# [Valid]  Loss: 0.1858 MAE: 1.6955 Best : 0.1839
# Epoch 26/99
# ----------
# [Train]  Loss: 0.2135 MAE: 1.9102 Best : 0.1839
# [Valid]  Loss: 0.1848 MAE: 1.6875 Best : 0.1839
# Epoch 27/99
# ----------
# [Train]  Loss: 0.2137 MAE: 1.9115 Best : 0.1839
# [Valid]  Loss: 0.1862 MAE: 1.6484 Best : 0.1839
# Epoch 28/99
# ----------
# [Train]  Loss: 0.2149 MAE: 1.9163 Best : 0.1839
# [Valid]  Loss: 0.1854 MAE: 1.7177 Best : 0.1839
# Epoch 29/99
# ----------
# [Train]  Loss: 0.2139 MAE: 1.9084 Best : 0.1839
# [Valid]  Loss: 0.1868 MAE: 1.6657 Best : 0.1839
# Epoch 30/99
# ----------
# [Train]  Loss: 0.2132 MAE: 1.9086 Best : 0.1839
# [Valid]  Loss: 0.1859 MAE: 1.7165 Best : 0.1839
# Epoch 31/99
# ----------
# [Train]  Loss: 0.2124 MAE: 1.9049 Best : 0.1839
# [Valid]  Loss: 0.1899 MAE: 1.7945 Best : 0.1839
# Epoch 32/99
# ----------
# [Train]  Loss: 0.2132 MAE: 1.9060 Best : 0.1839
# [Valid]  Loss: 0.1865 MAE: 1.7442 Best : 0.1839
# Epoch 33/99
# ----------
# [Train]  Loss: 0.2159 MAE: 1.9256 Best : 0.1839
# [Valid]  Loss: 0.1870 MAE: 1.6079 Best : 0.1839
# Epoch 34/99
# ----------
# [Train]  Loss: 0.2123 MAE: 1.8981 Best : 0.1839
# [Valid]  Loss: 0.1902 MAE: 1.5944 Best : 0.1839
# Epoch 35/99
# ----------
# [Train]  Loss: 0.2143 MAE: 1.9087 Best : 0.1839
# [Valid]  Loss: 0.1863 MAE: 1.6368 Best : 0.1839
# Epoch 36/99
# ----------
# [Train]  Loss: 0.2122 MAE: 1.9018 Best : 0.1839
# [Valid]  Loss: 0.1854 MAE: 1.7049 Best : 0.1839
# Epoch 37/99
# ----------
# [Train]  Loss: 0.2137 MAE: 1.9104 Best : 0.1839
# [Valid]  Loss: 0.1865 MAE: 1.7450 Best : 0.1839
# Epoch 38/99
# ----------
# [Train]  Loss: 0.2167 MAE: 1.9273 Best : 0.1839
# [Valid]  Loss: 0.1854 MAE: 1.6691 Best : 0.1839
# Epoch 39/99
# ----------
# [Train]  Loss: 0.2142 MAE: 1.9130 Best : 0.1839
# [Valid]  Loss: 0.1924 MAE: 1.8360 Best : 0.1839
# Epoch 40/99
# ----------
# [Train]  Loss: 0.2134 MAE: 1.9075 Best : 0.1839
# [Valid]  Loss: 0.1848 MAE: 1.6800 Best : 0.1839
# Epoch 41/99
# ----------
# [Train]  Loss: 0.2132 MAE: 1.9071 Best : 0.1839
# [Valid]  Loss: 0.1849 MAE: 1.6456 Best : 0.1839
# Epoch 42/99
# ----------
# [Train]  Loss: 0.2127 MAE: 1.9037 Best : 0.1839
# [Valid]  Loss: 0.1942 MAE: 1.8495 Best : 0.1839
# Epoch 43/99
# ----------
# [Train]  Loss: 0.2141 MAE: 1.9162 Best : 0.1839
# [Valid]  Loss: 0.1861 MAE: 1.6834 Best : 0.1839
# Epoch 44/99
# ----------
# [Train]  Loss: 0.2117 MAE: 1.8978 Best : 0.1839
# [Valid]  Loss: 0.1856 MAE: 1.7201 Best : 0.1839
# Epoch 45/99
# ----------
# [Train]  Loss: 0.2149 MAE: 1.9128 Best : 0.1839
# [Valid]  Loss: 0.1887 MAE: 1.7902 Best : 0.1839
# Epoch 46/99
# ----------
# [Train]  Loss: 0.2139 MAE: 1.9155 Best : 0.1839
# [Valid]  Loss: 0.1863 MAE: 1.7027 Best : 0.1839
# Epoch 47/99
# ----------
# [Train]  Loss: 0.2157 MAE: 1.9214 Best : 0.1839
# [Valid]  Loss: 0.1869 MAE: 1.7581 Best : 0.1839
# Epoch 48/99
# ----------
# [Train]  Loss: 0.2155 MAE: 1.9211 Best : 0.1839
# [Valid]  Loss: 0.1855 MAE: 1.7026 Best : 0.1839
# Epoch 49/99
# ----------
# [Train]  Loss: 0.2127 MAE: 1.9005 Best : 0.1839
# [Valid]  Loss: 0.1844 MAE: 1.6438 Best : 0.1839
# Epoch 50/99
# ----------
# [Train]  Loss: 0.2137 MAE: 1.9079 Best : 0.1839
# [Valid]  Loss: 0.1843 MAE: 1.6645 Best : 0.1839
# Epoch 51/99
# ----------
# [Train]  Loss: 0.2130 MAE: 1.9063 Best : 0.1839
# [Valid]  Loss: 0.1902 MAE: 1.7829 Best : 0.1839
# Epoch 52/99
# ----------
# [Train]  Loss: 0.2145 MAE: 1.9117 Best : 0.1839
# [Valid]  Loss: 0.1855 MAE: 1.7226 Best : 0.1839
# Epoch 53/99
# ----------
# [Train]  Loss: 0.2110 MAE: 1.8956 Best : 0.1839
# [Valid]  Loss: 0.1858 MAE: 1.6256 Best : 0.1839
# Epoch 54/99
# ----------
# [Train]  Loss: 0.2135 MAE: 1.9064 Best : 0.1839
# [Valid]  Loss: 0.1861 MAE: 1.7141 Best : 0.1839
# Epoch 55/99
# ----------
# [Train]  Loss: 0.2155 MAE: 1.9222 Best : 0.1839
# [Valid]  Loss: 0.1863 MAE: 1.7285 Best : 0.1839
# Epoch 56/99
# ----------
# [Train]  Loss: 0.2145 MAE: 1.9154 Best : 0.1839
# [Valid]  Loss: 0.1852 MAE: 1.7026 Best : 0.1839
# Epoch 57/99
# ----------
# [Train]  Loss: 0.2144 MAE: 1.9187 Best : 0.1839
# [Valid]  Loss: 0.1849 MAE: 1.6122 Best : 0.1839
# Epoch 58/99
# ----------
# [Train]  Loss: 0.2149 MAE: 1.9211 Best : 0.1839
# [Valid]  Loss: 0.1872 MAE: 1.6565 Best : 0.1839
# Epoch 59/99
# ----------
# [Train]  Loss: 0.2145 MAE: 1.9196 Best : 0.1839
# [Valid]  Loss: 0.1860 MAE: 1.6759 Best : 0.1839
# Epoch 60/99
# ----------
# [Train]  Loss: 0.2151 MAE: 1.9212 Best : 0.1839
# [Valid]  Loss: 0.1855 MAE: 1.6683 Best : 0.1839
# Epoch 61/99
# ----------
# [Train]  Loss: 0.2147 MAE: 1.9175 Best : 0.1839
# [Valid]  Loss: 0.1860 MAE: 1.7172 Best : 0.1839
# Epoch 62/99
# ----------
# [Train]  Loss: 0.2129 MAE: 1.9029 Best : 0.1839
# [Valid]  Loss: 0.1844 MAE: 1.6397 Best : 0.1839
# Epoch 63/99
# ----------
# [Train]  Loss: 0.2165 MAE: 1.9354 Best : 0.1839
# [Valid]  Loss: 0.1887 MAE: 1.5970 Best : 0.1839
# Epoch 64/99
# ----------
# [Train]  Loss: 0.2131 MAE: 1.8992 Best : 0.1839
# [Valid]  Loss: 0.1852 MAE: 1.7080 Best : 0.1839
# Epoch 65/99
# ----------
# [Train]  Loss: 0.2117 MAE: 1.9028 Best : 0.1839
# [Valid]  Loss: 0.1847 MAE: 1.6526 Best : 0.1839
# Epoch 66/99
# ----------
# [Train]  Loss: 0.2146 MAE: 1.9164 Best : 0.1839
# [Valid]  Loss: 0.1858 MAE: 1.7218 Best : 0.1839
# Epoch 67/99
# ----------
# [Train]  Loss: 0.2132 MAE: 1.9085 Best : 0.1839
# [Valid]  Loss: 0.1871 MAE: 1.7583 Best : 0.1839
# Epoch 68/99
# ----------
# [Train]  Loss: 0.2143 MAE: 1.9138 Best : 0.1839
# [Valid]  Loss: 0.1860 MAE: 1.6936 Best : 0.1839
# Epoch 69/99
# ----------
# [Train]  Loss: 0.2135 MAE: 1.9016 Best : 0.1839
# [Valid]  Loss: 0.1852 MAE: 1.6500 Best : 0.1839
# Epoch 70/99
# ----------
# [Train]  Loss: 0.2143 MAE: 1.9092 Best : 0.1839
# [Valid]  Loss: 0.1843 MAE: 1.6676 Best : 0.1839
# Epoch 71/99
# ----------
# [Train]  Loss: 0.2120 MAE: 1.9034 Best : 0.1839
# [Valid]  Loss: 0.1881 MAE: 1.7763 Best : 0.1839
# Epoch 72/99
# ----------
# [Train]  Loss: 0.2127 MAE: 1.9054 Best : 0.1839
# [Valid]  Loss: 0.1870 MAE: 1.6960 Best : 0.1839
# Epoch 73/99
# ----------
# [Train]  Loss: 0.2139 MAE: 1.9192 Best : 0.1839
# [Valid]  Loss: 0.1884 MAE: 1.7775 Best : 0.1839
# Epoch 74/99
# ----------
# [Train]  Loss: 0.2132 MAE: 1.9081 Best : 0.1839
# [Valid]  Loss: 0.1906 MAE: 1.8081 Best : 0.1839
# Epoch 75/99
# ----------
# [Train]  Loss: 0.2149 MAE: 1.9152 Best : 0.1839
# [Valid]  Loss: 0.1859 MAE: 1.7035 Best : 0.1839
# Epoch 76/99
# ----------
# [Train]  Loss: 0.2142 MAE: 1.9177 Best : 0.1839
# [Valid]  Loss: 0.1839 MAE: 1.6660 Best : 0.1839
# Epoch 77/99
# ----------
# [Train]  Loss: 0.2119 MAE: 1.8984 Best : 0.1839
# [Valid]  Loss: 0.1862 MAE: 1.7364 Best : 0.1839
# Epoch 78/99
# ----------
# [Train]  Loss: 0.2124 MAE: 1.9054 Best : 0.1839
# [Valid]  Loss: 0.1876 MAE: 1.7570 Best : 0.1839
# Epoch 79/99
# ----------
# [Train]  Loss: 0.2148 MAE: 1.9182 Best : 0.1839
# [Valid]  Loss: 0.1853 MAE: 1.7040 Best : 0.1839
# Epoch 80/99
# ----------
# [Train]  Loss: 0.2129 MAE: 1.9115 Best : 0.1839
# [Valid]  Loss: 0.1853 MAE: 1.7197 Best : 0.1839
# Epoch 81/99
# ----------
# [Train]  Loss: 0.2127 MAE: 1.9147 Best : 0.1839
# [Valid]  Loss: 0.1843 MAE: 1.6357 Best : 0.1839
# Epoch 82/99
# ----------
# [Train]  Loss: 0.2128 MAE: 1.9014 Best : 0.1839
# [Valid]  Loss: 0.1860 MAE: 1.6823 Best : 0.1839
# Epoch 83/99
# ----------
# [Train]  Loss: 0.2144 MAE: 1.9119 Best : 0.1839
# [Valid]  Loss: 0.1859 MAE: 1.6909 Best : 0.1839
# Epoch 84/99
# ----------
# [Train]  Loss: 0.2157 MAE: 1.9235 Best : 0.1839
# [Valid]  Loss: 0.1847 MAE: 1.6974 Best : 0.1839
# Epoch 85/99
# ----------
# [Train]  Loss: 0.2156 MAE: 1.9264 Best : 0.1839
# [Valid]  Loss: 0.1850 MAE: 1.6901 Best : 0.1839
# Epoch 86/99
# ----------
# [Train]  Loss: 0.2129 MAE: 1.9041 Best : 0.1839
# [Valid]  Loss: 0.1849 MAE: 1.6987 Best : 0.1839
# Epoch 87/99
# ----------
# [Train]  Loss: 0.2146 MAE: 1.9203 Best : 0.1839
# [Valid]  Loss: 0.1843 MAE: 1.6190 Best : 0.1839
# Epoch 88/99
# ----------
# [Train]  Loss: 0.2141 MAE: 1.9123 Best : 0.1839
# [Valid]  Loss: 0.1857 MAE: 1.6693 Best : 0.1839
# Epoch 89/99
# ----------
# [Train]  Loss: 0.2129 MAE: 1.9077 Best : 0.1839
# [Valid]  Loss: 0.1859 MAE: 1.6520 Best : 0.1839
# Epoch 90/99
# ----------
# [Train]  Loss: 0.2138 MAE: 1.9157 Best : 0.1839
# [Valid]  Loss: 0.1918 MAE: 1.6239 Best : 0.1839
# Epoch 91/99
# ----------
# [Train]  Loss: 0.2171 MAE: 1.9322 Best : 0.1839
# [Valid]  Loss: 0.1856 MAE: 1.6415 Best : 0.1839
# Epoch 92/99
# ----------
# [Train]  Loss: 0.2150 MAE: 1.9134 Best : 0.1839
# [Valid]  Loss: 0.1847 MAE: 1.6779 Best : 0.1839
# Epoch 93/99
# ----------
# [Train]  Loss: 0.2143 MAE: 1.9218 Best : 0.1839
# [Valid]  Loss: 0.1840 MAE: 1.6182 Best : 0.1839
# Epoch 94/99
# ----------
# [Train]  Loss: 0.2134 MAE: 1.9089 Best : 0.1839
# [Valid]  Loss: 0.1865 MAE: 1.6920 Best : 0.1839
# Epoch 95/99
# ----------
# [Train]  Loss: 0.2136 MAE: 1.9084 Best : 0.1839
# [Valid]  Loss: 0.1862 MAE: 1.7049 Best : 0.1839
# Epoch 96/99
# ----------
# [Train]  Loss: 0.2162 MAE: 1.9223 Best : 0.1839
# [Valid]  Loss: 0.1876 MAE: 1.6269 Best : 0.1839
# Epoch 97/99
# ----------
# [Train]  Loss: 0.2140 MAE: 1.9184 Best : 0.1839
# [Valid]  Loss: 0.1850 MAE: 1.7058 Best : 0.1839
# Epoch 98/99
# ----------
# [Train]  Loss: 0.2132 MAE: 1.9116 Best : 0.1839
# [Valid]  Loss: 0.1868 MAE: 1.7546 Best : 0.1839
# Epoch 99/99
# ----------
# [Train]  Loss: 0.2137 MAE: 1.9130 Best : 0.1839
# [Valid]  Loss: 0.1868 MAE: 1.7036 Best : 0.1839

# %%
plt.plot(pplIlllosses)
plt.plot(pplIllvalidlosses)

# %%
ft_idx = 1
may = [date for date in test_date if '2019-08' in date]
i3,i4 = 5,10
resultpdEIll = PredictionMultipleDate(modelPPLIll,test_date,may[i3], may[i4],loaderEIlltest, seq_len, scalersY, myfloor, ft_idx)
resultpdLux = PredictionMultipleDate(trainedLux,test_date,may[i3], may[i4],loaderLuxtest, seq_len, scalersY, myfloor, ft_idx)

# %%
resultpdEIll[["Truth","Prediction"]].plot(figsize=(18,5))#,title="Model_"+str(indexroom))
resultpdLux[["Truth","Prediction"]].plot(figsize=(18,5))#,title="Model_"+str(indexroom))
# Out:
# <AxesSubplot:>

# %%
torch.save(modelPPLIll.state_dict(), "./PPLIll.pt")
